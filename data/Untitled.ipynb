# %%
import json

# %%
with open('questions.json', 'r', encoding='utf-8') as file:
    game = json.load(file)
game
# Out:
# {'categories': [{'title': 'МММ',
#    'questions': [{'points': 100, 'audio': '2000s_100.mp3', 'answer': ''},
#     {'points': 200, 'audio': '2000s_200.mp3', 'answer': ''},
#     {'points': 300, 'audio': '2000s_300.mp3', 'answer': ''},
#     {'points': 400, 'audio': '2000s_400.mp3', 'answer': ''},
#     {'points': 500, 'audio': '2000s_500.mp3', 'answer': ''}]},
#   {'title': 'Русский поп',
#    'questions': [{'points': 100, 'audio': 'ruspop_100.mp3', 'answer': ''},
#     {'points': 200, 'audio': 'ruspop_200.mp3', 'answer': ''},
#     {'points': 300, 'audio': 'ruspop_300.mp3', 'answer': ''},
#     {'points': 400, 'audio': 'ruspop_400.mp3', 'answer': ''},
#     {'points': 500, 'audio': 'ruspop_500.mp3', 'answer': ''}]},
#   {'title': 'Зарубежный поп',
#    'questions': [{'points': 100, 'audio': 'intpop_100.mp3', 'answer': ''},
#     {'points': 200, 'audio': 'intpop_200.mp3', 'answer': ''},
#     {'points': 300, 'audio': 'intpop_300.mp3', 'answer': ''},
# ...

# %%
game['categories'][0]['title'] = 'МММ'

# %%
game
# Out:
# {'categories': [{'title': 'МММ',
#    'questions': [{'points': 100, 'audio': '2000s_100.mp3', 'answer': ''},
#     {'points': 200, 'audio': '2000s_200.mp3', 'answer': ''},
#     {'points': 300, 'audio': '2000s_300.mp3', 'answer': ''},
#     {'points': 400, 'audio': '2000s_400.mp3', 'answer': ''},
#     {'points': 500, 'audio': '2000s_500.mp3', 'answer': ''}]},
#   {'title': 'Русский поп',
#    'questions': [{'points': 100, 'audio': 'ruspop_100.mp3', 'answer': ''},
#     {'points': 200, 'audio': 'ruspop_200.mp3', 'answer': ''},
#     {'points': 300, 'audio': 'ruspop_300.mp3', 'answer': ''},
#     {'points': 400, 'audio': 'ruspop_400.mp3', 'answer': ''},
#     {'points': 500, 'audio': 'ruspop_500.mp3', 'answer': ''}]},
#   {'title': 'Зарубежный поп',
#    'questions': [{'points': 100, 'audio': 'intpop_100.mp3', 'answer': ''},
#     {'points': 200, 'audio': 'intpop_200.mp3', 'answer': ''},
#     {'points': 300, 'audio': 'intpop_300.mp3', 'answer': ''},
# ...

# %%
game['categories'][0]['questions'][-1]['audio'] = 'Isak_Danielson_Broken.mp3'

# %%
game['categories'][0]['questions'][-1]['answer'] = 'Isak Danielson - Broken'

# %%
with open('questions.json', 'w', encoding='utf-8') as file:
    json.dump(game, file)
